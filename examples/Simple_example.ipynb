# %% [markdown]
# # Application of Faraday Dreams on Real Data with and without the assumption of zero flux for $\lambda^2 \leq 0$ for the solution
#
# Then recovery is performed using Faraday Dreams + Optimus Primal on real data.

# %%
import sys
sys.path.insert(0,'..')
#put path to optimusprimal git repo
sys.path.insert(0,'../../Optimus-Primal')
import faradaydreams.measurement_operator as measurement_operator
import faradaydreams.models as models
import faradaydreams.recover_faraday_spectra as recover_faraday_spectra
import faradaydreams.utilities as utilities
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
plt.rcParams['font.size'] = '20'

# %% [markdown]
# Reads the data and sets up the observation

# %%
#data from http://vizier.u-strasbg.fr/viz-bin/VizieR-3?-source=J/ApJ/825/59/table6
table_data = Table.read("../data/anderson_rms.vot")
sources = np.array(np.unique(table_data['ID']))
def get_data(source, table_data, sigma_factor):
    data = table_data[table_data['ID']==source]
    y, weights, sigma =  utilities.get_polarization_and_weights(P_q=data['Q'], P_u=data['U'], error_q=data['e_Q'], error_u=data['e_U'])
    sigma = sig_factor * sigma
    freq = np.real(data["nu"]) * 10**9  # frequency coverage
    lambda2 = utilities.calculate_lambda2(freq=freq, dfreq=None)
    dphi = 15
    Nd = 320
    print(f'lambda2 max for FFT grid {np.max(np.fft.fftfreq(Nd, d=dphi) * np.pi)}')    
    print(f'lambda2 max from measurements {np.max(lambda2)}')  

    phi = measurement_operator.create_phi_array(Nd, dphi)
    return y, weights, phi, lambda2, freq, sigma

# %%
def plot_results(solution_negative, solution_positive, y, weights, phi, lambda2, freq0, rm_max, rm_min, output_name):
    sigma = np.mean(1/weights)
    weights = weights * sigma
    solution_negative[phi > rm_max] = 0
    solution_negative[phi < rm_min] = 0
    solution_positive[phi > rm_max] = 0
    solution_positive[phi < rm_min] = 0
    m_op = measurement_operator.faraday_operator(lambda2, phi, weights)
    buff = np.abs(np.abs(m_op.adj_op((y * 0. + weights)/np.sum(np.abs(weights)**2))) - 0.5)
    fwhm = np.abs(phi[int(len(buff)/2 - 5):int(len(buff)/2 + 5)][np.argmin(buff[int(len(buff)/2 - 5):int(len(buff)/2 + 5)])]) * 2
    sigma_phi = fwhm/2.355
    # measurement operator without channel averaging
    Nd = 320
    dphi = 15
    lambda2_high_res = measurement_operator.create_lambda2_array(Nd, dphi)
    m_op_no_averaging = measurement_operator.faraday_operator(lambda2_high_res, phi, lambda2_high_res * 0 + 1)
    fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(15, 15), dpi=80)
    ax[0].errorbar(lambda2, np.real(y), yerr=1/weights * sigma/np.sqrt(2), fmt='',linestyle='')
    ax[0].errorbar(lambda2, np.imag(y), yerr=1/weights * sigma/np.sqrt(2), fmt='',linestyle='')
    ax[0].errorbar(lambda2, np.abs(y), yerr=1/weights * sigma, fmt='',linestyle='')
    #ax[0].set_ylim([-np.max(np.abs(y)),np.max(np.abs(y))])
    ax[0].set_xlim([0,0.25**2])
    ax[0].set_xlabel(r"$\lambda^2$ (m^2)")
    ax[0].set_ylabel(r"(Jy)")
    ax[0].legend(["Observed (Real)", "Observed (Imag)", "Observed ||"])
    ax[1].plot(phi, np.abs(m_op.adj_op(y  * weights)) * 1./np.sum(weights**2)/sigma)
    ax[2].plot(phi, np.abs(m_op.adj_op((y * 0. + weights)/np.sum(np.abs(weights)**2))))
    ax[2].plot(phi, np.exp(-phi**2/(2 * sigma_phi**2)))
    ax[1].legend(["Dirty | |"])
    ax[1].set_xlabel(r"$\phi$ (rad/m$^2$)")
    ax[1].set_ylabel(r"(Jy)")
    ax[2].legend(["PSF | |"])
    ax[2].set_xlabel(r"$\phi$ (rad/m$^2$)")
    ax[2].set_ylabel(r"(Jy)")
    y_negative = m_op.dir_op(solution_negative) 
    y_positive = m_op.dir_op(solution_positive) 
    y_model_negative = m_op_no_averaging.dir_op(solution_negative)
    y_model_positive = m_op_no_averaging.dir_op(solution_positive) 
    index = np.abs(solution_positive) > np.max(solution_positive) * 0.1
    rm_val = np.sum((np.abs(solution_positive) * phi)[index])/np.sum(np.abs(solution_positive[index]))
    rm_std = np.sqrt(np.sum(np.abs(solution_positive[index]) * (rm_val - phi[index])**2)/np.sum(np.abs(solution_positive[index])))
    #print("rm value = ", rm_val)
    #print("rm std = ", rm_std)
    c =  299792458. 
    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(18, 6), dpi=80)
    ax = np.ravel(ax)
    ax[0].plot(lambda2_high_res, np.real(y_model_negative))
    ax[0].plot(lambda2_high_res, np.imag(y_model_negative))
    ax[0].plot(lambda2_high_res, np.real(y_model_positive))
    ax[0].plot(lambda2_high_res, np.imag(y_model_positive))
    ax[0].errorbar(lambda2, np.real(y), yerr=1/weights * sigma/np.sqrt(2), fmt='',linestyle='')
    ax[0].errorbar(lambda2, np.imag(y), yerr=1/weights * sigma/np.sqrt(2), fmt='',linestyle='')
    ax[0].set_ylim([-np.max(np.abs(y_model_negative)) * 1.5, np.max(np.abs(y_model_negative)) * 1.5])
    ax[0].set_xlabel(r"$\lambda^2$ (m$^2$)")
    ax[0].set_ylabel(r"(Jy)")
    ax[0].locator_params(axis="x", nbins=4)
    ax[0].locator_params(axis="y", nbins=4)
    ax[1].plot(phi, np.abs(solution_negative), c="teal")
    ax[1].plot(phi, np.abs(solution_positive), c="limegreen")
    ax[1].locator_params(axis="x", nbins=4)
    ax[1].locator_params(axis="y", nbins=4)
    ax[1].set_xlabel(r"$\phi$ (rad/m$^2$)")
    #ax[1].set_ylabel(r"(Jy)")
    ax[1].set_xlim([-500, 500])
    ax[2].plot(phi, np.abs(utilities.convolve_solution(solution_positive, phi, sigma_phi)), c="deeppink")
    ax[2].plot(phi, np.abs(utilities.convolve_solution(solution_negative, phi, sigma_phi)), c="indigo")
    ax[2].plot(phi, np.abs(utilities.convolve_solution(np.abs(solution_negative), phi, sigma_phi)), c="gold")
    ax[2].plot(phi, np.abs(utilities.convolve_solution(np.abs(solution_positive), phi, sigma_phi)), c="firebrick")
    ax[2].set_xlabel(r"$\phi$ (rad/m$^2$)")
    #ax[2].set_ylabel(r"(Jy)")
    ax[2].set_xlim([-500, 500])
    ax[2].locator_params(axis="x", nbins=4)
    ax[2].locator_params(axis="y", nbins=4)
    fig.tight_layout()
    #fig.savefig("output/"+str(output_name.decode("utf-8")) + ".png")
    #fig.savefig("output/"+str(output_name.decode("utf-8")) + ".pdf")
    ax[0].legend(["$Q^{\\rm Model}$", "$U^{\\rm Model}$", "$Q_{(\lambda^2 > 0)}^{\\rm Model}$", "$U_{(\lambda^2 > 0)}^{\\rm Model}$", "$Q^{\\rm Measured}$", "$U^{\\rm Measured}$"], fontsize=13,ncol=2)
    ax[1].legend(["$|F^{\\rm Model}|$" , "$|F_{(\lambda^2 > 0)}^{\\rm Model}|$"], fontsize=13)
    ax[2].legend(["$|F_{(\lambda^2 > 0)}^{\\rm Model, Convolved}|$", "$|F^{\\rm Model, Convolved}|$ ", "$|F^{\\rm Model}|_{\\rm Convolved}$", "$| F_{(\lambda^2 > 0)}^{\\rm Model}|_{\\rm Convolved}$"], fontsize=13)
    fig.tight_layout()
    #fig.savefig("output/"+str(output_name.decode("utf-8")) + "_labels.png")
    #fig.savefig("output/"+str(output_name.decode("utf-8")) + "_labels.pdf")
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 4), dpi=80)
    ax = np.ravel(ax)
    ax[0].loglog(c * np.sqrt(1/(lambda2_high_res[lambda2_high_res >= 0] + 1e-12))/10**9, np.abs(y_model_negative[lambda2_high_res >= 0]),c="hotpink")
    ax[0].loglog(c * np.sqrt(1/(lambda2_high_res[lambda2_high_res >= 0] + 1e-12))/10**9, np.abs(y_model_positive[lambda2_high_res >= 0]),c="mediumslateblue")
    ax[0].errorbar(freq0/10**9, np.abs(y), yerr=lambda2*0 + sigma * np.sqrt(2), fmt='',linestyle='',c="slategrey")
    ax[0].set_ylim([0.2e-3, 1e-1])
    ax[0].set_xlim([1, 1e2])
    ax[1].errorbar(freq0/10**9, np.real(y - y_negative/weights), yerr=lambda2*0 + sigma * np.sqrt(2), fmt='',linestyle='',c="blue")
    ax[1].errorbar(freq0/10**9, np.real(y - y_positive/weights), yerr=lambda2*0 + sigma * np.sqrt(2), fmt='',linestyle='',c="green")
    ax[1].errorbar(freq0/10**9, np.imag(y - y_negative/weights), yerr=lambda2*0 + sigma * np.sqrt(2), fmt='',linestyle='',c="orange")
    ax[1].errorbar(freq0/10**9, np.imag(y - y_positive/weights), yerr=lambda2*0 + sigma * np.sqrt(2), fmt='',linestyle='',c="red")
    ax[1].set_xlim([1, 10])
    ax[0].set_xlabel(r"$\nu$ (GHz)")
    ax[1].set_xlabel(r"$\nu$ (GHz)")
    ax[0].set_ylabel(r"(Jy)")
    #fig.savefig("output/"+str(output_name.decode("utf-8")) + "_freq.png")
    #fig.savefig("output/"+str(output_name.decode("utf-8")) + "_freq.pdf")
    ax[0].legend(["$|P^{\\rm Model}|$", "$|P_{(\lambda^2 > 0)}^{\\rm Model}|$", "$|P^{\\rm Measured}|$"], fontsize=16)    
    ax[1].legend(["$Q^{\\rm Res}$", "$Q_{(\lambda^2 > 0)}^{\\rm Res}$", "$U^{\\rm Res}$", "$U_{(\lambda^2 > 0)}^{\\rm Res}$"], fontsize=13, ncol=2) 
    fig.tight_layout()
    #fig.savefig("output/"+str(output_name.decode("utf-8")) + "_freq_labels.png")
    #fig.savefig("output/"+str(output_name.decode("utf-8")) + "_freq_labels.pdf")

# %%
def reconstruct_source(source, sigma_factor, rm_min, rm_max, beta1, beta2):
    data = table_data[table_data['ID']==source]
    freq = np.real(data["nu"]) * 10**9
    options = {'tol': 1e-5, 'iter': 50000, 'update_iter': 1000, 'record_iters': False, 'real': False, 'positivity': False, 'project_positive_lambda2': False}
    results_without_constraint = recover_faraday_spectra.recover_1d_faraday_spectrum(Q=data['Q'], U=data['U'], error_Q=data['e_Q'], error_U=data['e_U'], freq=freq, dphi=15, Nphi=320,
                                                                                     sigma_factor=sigma_factor, beta=beta1, options=options, channel_widths=None)
    options = {'tol': 1e-5, 'iter': 50000, 'update_iter': 1000, 'record_iters': False, 'real': False, 'positivity': False, 'project_positive_lambda2': True}
    results_with_constraint = recover_faraday_spectra.recover_1d_faraday_spectrum(Q=data['Q'], U=data['U'], error_Q=data['e_Q'], error_U=data['e_U'], freq=freq, dphi=15, Nphi=320, sigma_factor=sigma_factor, beta=beta2, options=options, channel_widths=None)
    plot_results(results_without_constraint["solution"], results_with_constraint["solution"], results_without_constraint["measurements"], results_without_constraint["measurements_weights"], results_without_constraint["phi"], results_without_constraint["measurements_lambda2"], freq, rm_max, rm_min, source)

# %%
print(sources)
print(len(sources))
# Out:
# [b'0515-674' b'1315-46' b'cena_c1093' b'cena_c1152' b'cena_c1435'
#  b'cena_c1466' b'cena_c1573' b'cena_c1636' b'cena_c1640' b'cena_c1748'
#  b'cena_c1764' b'cena_c1827' b'cena_c1832' b'cena_c1972' b'cena_s1014'
#  b'cena_s1031' b'cena_s1290' b'cena_s1349' b'cena_s1382' b'cena_s1437'
#  b'cena_s1443' b'cena_s1568' b'cena_s1605' b'cena_s1681' b'cena_s1803'
#  b'lmc_c01' b'lmc_c02' b'lmc_c03' b'lmc_c04' b'lmc_c06' b'lmc_c07'
#  b'lmc_c15' b'lmc_c16' b'lmc_s11' b'lmc_s13' b'lmc_s14']
# 36

# %%
source = sources[13]
print(source)
sig_factor = 1
rm_max = 2000
rm_min = -2000
beta1, beta2 = 1e-4, 1e-4
reconstruct_source(source, sig_factor, rm_min, rm_max, beta1, beta2)
# Out:
# b'cena_c1972'
# 2021-10-07 15:31:31,222 - Optimus Primal - INFO - Starting Power method
# 2021-10-07 15:31:31,223 - Optimus Primal - INFO - [Power Method] iter = 1, tol = 0.0
# 2021-10-07 15:31:31,226 - Optimus Primal - INFO - [Power Method] iter = 11, tol = 0.0
# 2021-10-07 15:31:31,228 - Optimus Primal - INFO - [Power Method] Converged with norm= 6883.771003707467, iter = 15, tol = 8.337607038731532e-05
# 2021-10-07 15:31:31,229 - Faraday Dreams - INFO - Using wavelets ['dirac'] with 1 levels
# 2021-10-07 15:32:04,851 - Optimus Primal - INFO - [Primal Dual] 40000 out of 50000 iterations, tol = 0.000749
# 2021-10-07 15:32:05,248 - Optimus Primal - INFO - [Primal Dual] 41000 out of 50000 iterations, tol = 0.000155
# 2021-10-07 15:32:05,643 - Optimus Primal - INFO - [Primal Dual] 42000 out of 50000 iterations, tol = 0.000657
# 2021-10-07 15:32:06,061 - Optimus Primal - INFO - [Primal Dual] 43000 out of 50000 iterations, tol = 0.000139
# 2021-10-07 15:32:06,464 - Optimus Primal - INFO - [Primal Dual] 44000 out of 50000 iterations, tol = 0.000572
# 2021-10-07 15:32:06,862 - Optimus Primal - INFO - [Primal Dual] 45000 out of 50000 iterations, tol = 0.000129
# 2021-10-07 15:32:07,299 - Optimus Primal - INFO - [Primal Dual] 46000 out of 50000 iterations, tol = 0.000500
# 2021-10-07 15:32:07,707 - Optimus Primal - INFO - [Primal Dual] 47000 out of 50000 iterations, tol = 0.000119
# 2021-10-07 15:32:08,117 - Optimus Primal - INFO - [Primal Dual] 48000 out of 50000 iterations, tol = 0.000435
# 2021-10-07 15:32:08,521 - Optimus Primal - INFO - [Primal Dual] 49000 out of 50000 iterations, tol = 0.000107

# %%
source = sources[31]
print(source)
sig_factor = 1
rm_max = 1000
rm_min = -1000
beta1, beta2 = 4e-4, 4e-4
reconstruct_source(source, sig_factor, rm_min, rm_max, beta1, beta2)
# Out:
# b'lmc_c15'
# 2021-10-07 15:32:34,112 - Optimus Primal - INFO - Starting Power method
# 2021-10-07 15:32:34,114 - Optimus Primal - INFO - [Power Method] iter = 1, tol = 0.0
# 2021-10-07 15:32:34,116 - Optimus Primal - INFO - [Power Method] Converged with norm= 23541.123836844017, iter = 4, tol = 1.3851353834702452e-05
# 2021-10-07 15:32:34,117 - Faraday Dreams - INFO - Using wavelets ['dirac'] with 1 levels
# 2021-10-07 15:32:34,118 - Faraday Dreams - INFO - Using an estimated noise level of 0.0014450696762651205 (Jy)
# 2021-10-07 15:32:34,119 - Faraday Dreams - INFO - Reconstructing Faraday Depth using constrained l1 regularization
# 2021-10-07 15:32:34,120 - Optimus Primal - INFO - Running Forward Backward Primal Dual
# 2021-10-07 15:32:34,122 - Optimus Primal - INFO - [Primal Dual] 0 out of 50000 iterations, tol = 0.000000
# 2021-10-07 15:32:34,532 - Optimus Primal - INFO - [Primal Dual] 1000 out of 50000 iterations, tol = 0.005831
# 2021-10-07 15:32:34,912 - Optimus Primal - INFO - [Primal Dual] 2000 out of 50000 iterations, tol = 0.004331
# 2021-10-07 15:32:35,301 - Optimus Primal - INFO - [Primal Dual] 3000 out of 50000 iterations, tol = 0.002675
# 2021-10-07 15:32:35,692 - Optimus Primal - INFO - [Primal Dual] 4000 out of 50000 iterations, tol = 0.001088
# 2021-10-07 15:32:36,069 - Optimus Primal - INFO - [Primal Dual] 5000 out of 50000 iterations, tol = 0.001875
# 2021-10-07 15:32:36,436 - Optimus Primal - INFO - [Primal Dual] 6000 out of 50000 iterations, tol = 0.004104
# 2021-10-07 15:32:45,914 - Optimus Primal - INFO - [Primal Dual] 32000 out of 50000 iterations, tol = 0.000118
# 2021-10-07 15:32:46,281 - Optimus Primal - INFO - [Primal Dual] 33000 out of 50000 iterations, tol = 0.000130
# 2021-10-07 15:32:46,642 - Optimus Primal - INFO - [Primal Dual] 34000 out of 50000 iterations, tol = 0.000196
# 2021-10-07 15:32:47,009 - Optimus Primal - INFO - [Primal Dual] 35000 out of 50000 iterations, tol = 0.000247
# 2021-10-07 15:32:47,382 - Optimus Primal - INFO - [Primal Dual] 36000 out of 50000 iterations, tol = 0.000264
# 2021-10-07 15:32:47,744 - Optimus Primal - INFO - [Primal Dual] 37000 out of 50000 iterations, tol = 0.000252
# 2021-10-07 15:32:48,110 - Optimus Primal - INFO - [Primal Dual] 38000 out of 50000 iterations, tol = 0.000226
# 2021-10-07 15:32:48,472 - Optimus Primal - INFO - [Primal Dual] 39000 out of 50000 iterations, tol = 0.000185
# 2021-10-07 15:32:48,831 - Optimus Primal - INFO - [Primal Dual] 40000 out of 50000 iterations, tol = 0.000146
# 2021-10-07 15:32:49,191 - Optimus Primal - INFO - [Primal Dual] 41000 out of 50000 iterations, tol = 0.000104
# 2021-10-07 15:32:49,556 - Optimus Primal - INFO - [Primal Dual] 42000 out of 50000 iterations, tol = 0.000085
# 2021-10-07 15:32:49,923 - Optimus Primal - INFO - [Primal Dual] 43000 out of 50000 iterations, tol = 0.000113
# 2021-10-07 15:32:50,288 - Optimus Primal - INFO - [Primal Dual] 44000 out of 50000 iterations, tol = 0.000152
# 2021-10-07 15:32:50,648 - Optimus Primal - INFO - [Primal Dual] 45000 out of 50000 iterations, tol = 0.000177
# 2021-10-07 15:32:51,020 - Optimus Primal - INFO - [Primal Dual] 46000 out of 50000 iterations, tol = 0.000176
# 2021-10-07 15:32:51,386 - Optimus Primal - INFO - [Primal Dual] 47000 out of 50000 iterations, tol = 0.000155
# 2021-10-07 15:32:51,757 - Optimus Primal - INFO - [Primal Dual] 48000 out of 50000 iterations, tol = 0.000128
# 2021-10-07 15:32:52,121 - Optimus Primal - INFO - [Primal Dual] 49000 out of 50000 iterations, tol = 0.000098
# 2021-10-07 15:32:52,497 - Optimus Primal - INFO - Starting Power method
# 2021-10-07 15:32:52,498 - Optimus Primal - INFO - [Power Method] iter = 1, tol = 0.0
# 2021-10-07 15:32:52,499 - Optimus Primal - INFO - [Power Method] Converged with norm= 23541.123836844017, iter = 4, tol = 1.3851353834702452e-05
# 2021-10-07 15:32:52,500 - Faraday Dreams - INFO - Using wavelets ['dirac'] with 1 levels
# 2021-10-07 15:32:52,500 - Faraday Dreams - INFO - Using an estimated noise level of 0.0014450696762651205 (Jy)
# 2021-10-07 15:32:52,501 - Faraday Dreams - INFO - Reconstructing Faraday Depth using constrained l1 regularization
# 2021-10-07 15:32:52,502 - Optimus Primal - INFO - Running Forward Backward Primal Dual
# 2021-10-07 15:32:52,504 - Optimus Primal - INFO - [Primal Dual] 0 out of 50000 iterations, tol = 0.000000
# 2021-10-07 15:32:52,935 - Optimus Primal - INFO - [Primal Dual] 1000 out of 50000 iterations, tol = 0.006722
# 2021-10-07 15:32:53,338 - Optimus Primal - INFO - [Primal Dual] 2000 out of 50000 iterations, tol = 0.004141
# 2021-10-07 15:32:53,741 - Optimus Primal - INFO - [Primal Dual] 3000 out of 50000 iterations, tol = 0.004434
# 2021-10-07 15:32:54,144 - Optimus Primal - INFO - [Primal Dual] 4000 out of 50000 iterations, tol = 0.002698
# 2021-10-07 15:32:54,548 - Optimus Primal - INFO - [Primal Dual] 5000 out of 50000 iterations, tol = 0.004490
# 2021-10-07 15:32:54,947 - Optimus Primal - INFO - [Primal Dual] 6000 out of 50000 iterations, tol = 0.004318
# 2021-10-07 15:32:55,342 - Optimus Primal - INFO - [Primal Dual] 7000 out of 50000 iterations, tol = 0.003689
# 2021-10-07 15:32:55,733 - Optimus Primal - INFO - [Primal Dual] 8000 out of 50000 iterations, tol = 0.004505
# 2021-10-07 15:32:56,136 - Optimus Primal - INFO - [Primal Dual] 9000 out of 50000 iterations, tol = 0.004129
# 2021-10-07 15:32:56,544 - Optimus Primal - INFO - [Primal Dual] 10000 out of 50000 iterations, tol = 0.002910
# 2021-10-07 15:32:56,951 - Optimus Primal - INFO - [Primal Dual] 11000 out of 50000 iterations, tol = 0.002391
# 2021-10-07 15:32:57,385 - Optimus Primal - INFO - [Primal Dual] 12000 out of 50000 iterations, tol = 0.002452
# 2021-10-07 15:32:57,810 - Optimus Primal - INFO - [Primal Dual] 13000 out of 50000 iterations, tol = 0.002064
# 2021-10-07 15:32:58,255 - Optimus Primal - INFO - [Primal Dual] 14000 out of 50000 iterations, tol = 0.001989
# 2021-10-07 15:32:58,676 - Optimus Primal - INFO - [Primal Dual] 15000 out of 50000 iterations, tol = 0.002071
# 2021-10-07 15:32:59,110 - Optimus Primal - INFO - [Primal Dual] 16000 out of 50000 iterations, tol = 0.002342
# 2021-10-07 15:32:59,534 - Optimus Primal - INFO - [Primal Dual] 17000 out of 50000 iterations, tol = 0.002295
# 2021-10-07 15:32:59,953 - Optimus Primal - INFO - [Primal Dual] 18000 out of 50000 iterations, tol = 0.002543
# 2021-10-07 15:33:00,385 - Optimus Primal - INFO - [Primal Dual] 19000 out of 50000 iterations, tol = 0.001780
# 2021-10-07 15:33:00,814 - Optimus Primal - INFO - [Primal Dual] 20000 out of 50000 iterations, tol = 0.001734
# 2021-10-07 15:33:01,238 - Optimus Primal - INFO - [Primal Dual] 21000 out of 50000 iterations, tol = 0.001523
# 2021-10-07 15:33:01,680 - Optimus Primal - INFO - [Primal Dual] 22000 out of 50000 iterations, tol = 0.001380
# 2021-10-07 15:33:02,121 - Optimus Primal - INFO - [Primal Dual] 23000 out of 50000 iterations, tol = 0.000909
# 2021-10-07 15:33:02,547 - Optimus Primal - INFO - [Primal Dual] 24000 out of 50000 iterations, tol = 0.001267
